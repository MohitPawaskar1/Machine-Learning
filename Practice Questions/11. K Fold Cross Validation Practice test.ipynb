# %%
# Importing all the libraries

import numpy as np
import pandas as pd
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.datasets import load_iris

# %%
# Importing the Datasert

iris = load_iris()

# %%
# Printing the Score of the LogisticRegression using the cross_val_score

lr = cross_val_score(LogisticRegression(max_iter=1000), iris.data, iris.target, cv=3)
print(f'The Scores for Logistic Regression are {lr}')
# Out:
# The Scores for Logistic Regression are [0.98 0.96 0.98]

# %%
# Printing the Score of the SVC using the cross_val_score

svm = cross_val_score(SVC(), iris.data, iris.target, cv=3)
print(f'The Scores for Logistic Regression are {svm}')
# Out:
# The Scores for Logistic Regression are [0.96 0.98 0.94]

# %%
# Printing the Score of the RandomForestClassifier using the cross_val_score

rf = cross_val_score(RandomForestClassifier(n_estimators=40), iris.data, iris.target, cv=3)
print(f'The Scores for Logistic Regression are {rf}')
# Out:
# The Scores for Logistic Regression are [0.98 0.92 0.98]

# %%
print(f'LogisticRegression is giving the Best Score among all')
# Out:
# LogisticRegression is giving the Best Score among all
